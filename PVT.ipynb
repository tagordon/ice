# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
V, T, P, ref = np.loadtxt('VTP.txt').T

fig = plt.figure(figsize = (14, 9))
ax = plt.axes(projection ='3d')
ax.scatter(T, P, 1/V, c=1/V, alpha=1)

# %%
from scipy.interpolate import bisplrep, bisplev

tck = bisplrep(P, T, 1/V, kx=3, ky=3)

Pi = np.linspace(0, 300, 100)
Ti = np.linspace(0, 2000, 100)
z = bisplev(Pi, Ti, tck).T

x, y = np.meshgrid(Pi, Ti)

fig = plt.figure(figsize = (14, 9))
ax = plt.axes(projection ='3d')

ax.scatter(T, P, 1/V, c='k', alpha=1)
ax.scatter(y, x, z, c=densi)
